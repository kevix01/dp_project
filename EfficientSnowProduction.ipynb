# %% [markdown]
# # Sistema di produzione di neve artificiale
# ---

# %% [markdown]
# ## Descrizione e formulazione del problema

# %% [markdown]
# - orizzonte temporale: $t=0,1,...T$, $T = 72$ ore considerando un time step orario
# - stato $x_t: (temperatura\_ora\_t,umidità\_ora\_t,livello\_neve\_ora\_t) = (T_t,RH_t,d_t) = (i,j,k)$
# - spazio degli stati $x_t \in X_t=\{(i,j,k): i=1,...,30, j=1,...,30, k=1,...,201\}$
#     - $T_t \in\{T_1,...,T_{30}\}_t$ con valori diversi da ora in ora
#         - $T_t$ variabile aleatoria discreta con pmf $P(T_t=T_i)_t$
#     - $RH_t \in\{RH_1,...,RH_{30}\}_t$ con valori diversi da ora in ora
#         - $RH_t$ variabile aleatoria discreta con pmf $P(RH_t=RH_i)_t$
#     - $d_t \in D=\{0,...,100\}, |D|=n$
# - ingresso $u_t=(af_t,wf_t)$
#     - $af_t$: flusso di aria iniettato nella macchina sparaneve nell'ora t $[m^3/h]$
#     - $wf_t$: flusso di acqua iniettato nella macchina sparaneve nell'ora t $[m^3/h]$
# - spazio degli ingressi $u_t \in U=
#     \begin{cases}
#     \{(0,0)\} & \text{se } \text{la } \text{neve } \text{non } \text{può } \text{essere } \text{prodotta } \text{dati } (T_t,RH_t) \\
#     \{(min_{af},min_{wf}),...,(max_{af},max_{wf})\} & \text{altrimenti }
#     \end{cases}$
#     - $min_{wf} = 0.6 [m^3/h], max_{wf} = [3.6,5.4] [m^3/h]$
#         - step di discretizzazione: $0.2$
#     - $min_{af} = 6 [m^3/h], max_{af} = 27 [m^3/h]$
#         - step di dicretizzazione: $1$
#     - la neve non può essere prodotta se la temperatura del bulbo umido è superiore alla soglia operativa $T_{wb,soglia} = -2.5 °C$
# - matrice di transizione per le componenti di temperatura e umidità dello stato
#     - $P((T_{t+1}=i,RH_{t+1}=j)|(T_{t}=i',RH_{t}=j'))=P(T_{t+1}=i|T_t=i')_{t+1}*P(RH_{t+1}=j|RH_t=j')_{t+1}$
# - funzione di transizione per la componente "livello_neve" dello stato
#     - $d_{t+1}=d_t+Neve\_prodotta(x_t,u_t)-Neve\_fusa(x_t)$
#     - valore da approssimare al valore discreto più vicino assunto da $d_t$
# - funzione per determinare la neve prodotta in un time step in $m^3$
#     - $Neve\_prodotta(T_t,RH_t,af_t,wf_t)=k(T_t,RH_t)*min(af_t,wf_t)$
#     - $k=\alpha * max(0,T_{wb,soglia}-T_{wb})$ coefficiente di efficienza
#     - $\alpha:$ coefficiente calibrato $\in [0.4,1]$
#     - $T_{wb,soglia} = -2.5 °C$: soglia (wet-bulb) operativa del generatore
#     - $T_{wb} ≈ T_t ⋅arctan(0.151977⋅(RH_t+8.313659)^{0.5})+arctan(T_t+RH_t)-arctan(RH_t−1.676331)
# +0.00391838⋅RH^{1.5}⋅arctan(0.023101⋅RH)−4.686035$
#         - dove $T_t$ in $°C$ e $RH_t$ in percentuale
# - funzione per determinare la neve fusa in un time step in $m^3$
#     - $Neve\_fusa(x_t)= [(DHF * max(T_{t}-T_0,0) * humidity\_factor)/1000] * A$
#         - $DHF = degree-hour-factor (mm/°C/ora)$ (settata a 0.7)
#         - $T_{t} = temperatura °C$ (che si verifica nell'ora attuale)
#         - $humidity\_factor = 0.5 + 0.5 * RH$ (dove RH è l'umidità nell'ora attuale)
#         - $T_0 = soglia (≈°C)$ (settata a 0)
#         - $A = area (m^2)$ (settata a 30)
# - stage cost $g(u_t):$ deterministico, tempo-invariante
#     - $g(u_t)=prezzo\_energia*(E_{ventola}+E_{compressore}(u_t)+E_{pompa}(u_t))$
#     - $prezzo\_energia = 0.25 \text{€}/kWh $
#     - $E_{ventola}=18.5 kWh$ costante
#     - $E_{compressore}(u_t)= e * af_t * 60$
#         - $e=6.2 [kW/(m^3/min)]$
#         - $af_t [m^3/h]$
#     - $E_{pompa}(u_t)=k_{pump}*wf_t$
#         - $k_{pump}=2.7 [kWh/m^3]$
#         - $af_t [m^3/h]$
# - Terminal cost $g_T(x_T)$:
#     - $g_T((i,j,k)) = \begin{cases} 0 & \text{if } k \geq 80 \\ (10^3) & \text{if } k < 80  \end{cases}$
#     - costo infinito se non viene prodotta almeno $40 [m^3]$ di neve al termine dell'orizzonte temporale

# %% [markdown]
# ## Formulazione del problema
# ---

# %% [markdown]
# ### Importazione moduli

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import json
import math 
from functions import *
from numba import njit, prange
import os

# %% [markdown]
# ### Parametri del problema

# %%
# Stato
n_fasce=24 #fasce orarie
n_T = 30 #numero di intervalli di discretizzazione di temperatura
n_RH = 30 #numero di intervalli di discretizzazione di umidità
n_T_RH = n_T * n_RH #numero di possibili combinazioni di temperatura e umidità per fascia oraria
max_d=100 #profondità massima della neve
step_d=0.5 #step di discretizzazione della profondità della neve
# Ingresso
# - flusso di aria minimo e massimo in ingresso allo sparaneve
min_af=6
max_af=27
af_step=1 #step di discretizzazione del flusso di aria
# - flusso di acqua minimo e massimo in ingresso allo sparaneve
min_wf=0.6
max_wf=4.5 #[3.6,5.4]
wf_step=0.2 #step di discretizzazione del flusso di acqua
# Stato terminale
d_target=40 #livello di neve che deve essere raggiunta in m^3
penalization_cost=5e3 #costo terminale nel caso in cui la profondità target non venga raggiunta

# %% [markdown]
# ### Caricamento dati meteorologici da file

# %%
# CARICAMENTO DATI temperatura e umidità DA FILE JSON
with open("pmf_temperature.json", "r", encoding="utf-8") as f1:
    temperature = json.load(f1)

with open("pmf_humidity.json", "r", encoding="utf-8") as f2:
    humidity = json.load(f2)

# conversione dei dizionari in liste
# - temperatura
temp_val=np.empty((n_fasce,n_T)) #valori discreti per fasce orarie
temp_pmf=np.empty((n_fasce,n_T)) #pmf per fasce orarie
f=0
for fasce,dict_val in temperature.items():
    temp_val[f]=np.array(dict_val['values'],dtype=np.float32)
    temp_pmf[f]=np.array(dict_val['pmf'],dtype=np.float32)
    f+=1
    
# - umidità
humid_val=np.empty((n_fasce,n_RH)) #valori discreti per fasce orarie
humid_pmf=np.empty((n_fasce,n_RH)) #pmf per fasce orarie
f=0
for fasce,dict_val in humidity.items():
    humid_val[f]=np.array(dict_val['values'],dtype=np.float32)
    humid_pmf[f]=np.array(dict_val['pmf'],dtype=np.float32)
    f+=1

# caricamento delle matrici delle probabilità condizionate da file
P_T_list = load_transition_matrices("transition_T.json") #lista di matrici P_T, una per ogni fascia oraria
P_RH_list = load_transition_matrices("transition_RH.json") #lista di matrici P_RH, una per ogni fascia oraria

print("Caricate", len(P_T_list), "matrici di transizione T")
print("Caricate", len(P_RH_list), "matrici di transizione RH")
#print("Dimensione prima matrice T:", P_T_list[0].shape)
#print(P_T_list[0])
# Out:
# Caricate 24 matrici di transizione T
# Caricate 24 matrici di transizione RH

# %% [markdown]
# ### Definizione spazio degli stati e degli ingressi

# %%
# Definizione dello spazio dei valori discreti della profondità della neve
depth_space=np.arange(0,max_d+step_d,step_d,dtype=np.float32)
n_d=depth_space.shape[0] ##numero di intervalli di discretizzazione della profondità della neve

# Spazio degli stati
state_space=np.empty((n_fasce,n_T,n_RH,n_d,3))
n_states=n_T*n_RH*n_d #numero di stati per fascia oraria
# - definizione di uno spazio degli stati per ogni fascia oraria
for f in range(n_fasce):
    X=np.empty((n_T,n_RH,n_d,3),dtype=np.float32)
    for i,T in enumerate(temp_val[f]):
        for j,RH in enumerate(humid_val[f]):
            for k,d in enumerate(depth_space):            
                X[i,j,k]=[T,RH,d]
    state_space[f]=X

print(state_space[0].shape)
#print(state_space[0])

# Spazio degli ingressi
af_val=np.arange(min_af,max_af+af_step,af_step,dtype=np.float32)
af_n_val=af_val.shape[0]
wf_val=np.arange(min_wf,max_wf+wf_step,wf_step,dtype=np.float32)
wf_n_val=wf_val.shape[0]
U_default=np.empty((af_n_val*wf_n_val,2),dtype=np.float32)
for i,af in enumerate(af_val):
    for j,wf in enumerate(wf_val):
        U_default[i*wf_n_val+j]=[af,wf]
#U=input_space(-1,90,min_af, max_af, min_wf, max_wf, af_step, wf_step)
# Out:
# (30, 30, 201, 3)

# %% [markdown]
# ### Definizione stage cost e terminal cost

# %%
@njit
def stage_cost(x_t,u_t):
    T_t=x_t[0]
    RH_t=x_t[1]
    af_t=u_t[0]
    wf_t=u_t[1]
    energy_price=0.25 #€/kWh
    E_fan=18.5 #kWh
    e=6.2 #kW/(m^3/min)
    E_compressor=e*af_t #kWh
    k_pump=2.7 #kWh/m^3 ~0.2–2.7 kWh/m³
    E_pump=k_pump*wf_t #kWh 
    return energy_price*(E_fan+E_compressor+E_pump)

@njit
def terminal_cost(x_T):
    d_t=x_T[2]
    if d_t<d_target:
        return penalization_cost
    else:
        return 0

# test della funzione stage_cost
print(stage_cost(np.array([temp_val[0][15],humid_val[0][25]],dtype=np.float32),np.array([10,2.5],dtype=np.float32)))
# Out:
# 21.8125

# %% [markdown]
# ### Definizione della dinamica del sistema
# ---

# %% [markdown]
# #### Matrici P per la transizione di temperatura e umidità

# %%
# Calcolo matrici P_t di transizione delle componenti temperatura e umidità dello stato
# --> P_list conterrà una matrice di transizione per fascia oraria
P_list = np.empty((n_fasce,n_T_RH,n_T_RH))

for f in range(n_fasce):
    P_T = P_T_list[f] #matrice delle probabilità condizionate della temperatura relativa alla fascia f
    P_RH = P_RH_list[f] #matrice delle probabilità condizionate dell'umidità relativa alla fascia f
    P_list[f]=build_joint_transition(P_T, P_RH)

print(P_list[0].shape)
#print(P_list[0])
# Out:
# (900, 900)

# %% [markdown]
# #### Funzione per la transizione della profondità della neve

# %%
# - funzione di transizione per la componente 'profondità_neve' dello stato (deterministica)
@njit
def depth_transition(x_t,u_t):
    T_t=x_t[0]
    RH_t=x_t[1]
    d_t=x_t[2]
    af_t=u_t[0]
    wf_t=u_t[1]
    # profondità della neve al prossimo time step (fascia oraria)
    d_next=d_t+snow_produced(T_t,RH_t,af_t,wf_t)-snow_melted(T_t,RH_t)
    if d_next<0:
        d_next_discretized=np.float32(0)
    else: # arrotondamento al campione discreto più vicino
        d_next_discretized=depth_space[np.argmin(np.abs(depth_space-d_next))]
    return d_next_discretized

# test della funzione 
x_t=np.array([-13.805833333333334,26.206190154216248,5],dtype=np.float32)
u_t=np.array([10,3],dtype=np.float32)
print(depth_transition(x_t,u_t))
# Out:
# 19.5

# %% [markdown]
# #### Stato iniziale

# %%
# - funzione che restituisce uno stato iniziale secondo le distribuzioni di temperatura e umidità nella fascia oraria iniziale
# - e secondo la profondità iniziale della neve passata come parametro
def get_initial_state(f_t0,d0):
    # --> f_t0: fascia oraria dell'istante di tempo iniziale t0 del time horizon
    # da aggiungere il controllo della fascia oraria
    pmf_T_t0=temp_pmf[f_t0] # pmf temperatura nella fascia f_t0
    pmf_RH_t0=humid_pmf[f_t0] # pmf umidità nella fascia f_t0
    T0=np.random.choice(temp_val[f_t0], p=pmf_T_t0) # estrazione di un campione di temperatura dalla relativa pmf
    RH0=np.random.choice(humid_val[f_t0], p=pmf_RH_t0) # estrazione di un campione di umidità dalla relativa pmf
    x_0=np.array([T0,RH0,d0],dtype=np.float32)
    return x_0
# test della funzione
print(get_initial_state(0,depth_space[-1]))
# Out:
# [ -2.7785    61.751633 100.      ]

# %% [markdown]
# #### Evoluzione meteorologica del sistema

# %%
# - evoluzione di uno step per temperatura e umidità, secondo la matrice di transizione realtiva alla fascia f
def weather_transition(x_t,f): #da aggiungere la rotazione delle fasce --> 23 - 0
    T_t=x_t[0]
    RH_t=x_t[1]
    # matrice di transizione relativa alla fascia f
    P_f = P_list[f] 
    # conversione stato in indice
    state_idx = state_to_index(T_t,RH_t,temp_val[f],humid_val[f])
    # estrazione di un campione secondo la pmf condizionata allo stato corrente, presente nella matrice P_f
    next_state_idx = np.random.choice(np.arange(0,n_T_RH,1), p=P_f[state_idx]) 
    # conversione indice ottenuto in stato
    if f<23:
        next_T, next_RH = index_to_state(next_state_idx,temp_val[f+1],humid_val[f+1])
    else: #siamo nell'ultima fascia oraria, i prossimi valori da considerare per temperatura e umidità vengono presi dalla fascia 0
        next_T, next_RH = index_to_state(next_state_idx,temp_val[0],humid_val[0])
    return next_T, next_RH
# test della funzione
#print(weather_transition(x_t,0))

# - simulazione dell'andamento di temperatura e umidità per un singolo time horizon t=0,...,T
def simulate_weather_transition(T,print_enabled=False):
    # --> T: lunghezza time horizon
    X_sim=np.empty((T,2)) #lista degli stati (Temperatura,Umidità) visitati dal sistema durante la simulazione
    f_t0=0 #fascia oraria a cui appartiene t0
    x_0=get_initial_state(f_t0,depth_space[0]) #la profonditò della neve viene impostata a 0
    # inizializzazione
    u_t=np.array([0,0],dtype=np.float32)
    x_t=x_0
    f_t=f_t0
    # iterazione
    for t in range(T):
        next_T, next_RH = weather_transition(x_t,f_t)
        x_tp1 = np.array([next_T,next_RH],dtype=np.float32)
        X_sim[t]=x_tp1
        if print_enabled: print(f"time {t}, fascia {f_t}, T={x_tp1[0]:.2f} RH={x_tp1[1]:.2f}")
        x_t=x_tp1
        f_t=(t+1)%24
    return X_sim
# test della funzione
X_sim=simulate_weather_transition(72,print_enabled=True)
# Out:
# time 0, fascia 0, T=6.40 RH=54.87
# time 1, fascia 1, T=5.30 RH=53.97
# time 2, fascia 2, T=4.24 RH=54.85
# time 3, fascia 3, T=4.14 RH=45.46
# time 4, fascia 4, T=4.00 RH=41.67
# time 5, fascia 5, T=4.15 RH=43.83
# time 6, fascia 6, T=2.95 RH=48.80
# time 7, fascia 7, T=3.98 RH=47.23
# time 8, fascia 8, T=8.33 RH=43.38
# time 9, fascia 9, T=9.73 RH=26.52
# time 10, fascia 10, T=11.32 RH=30.52
# time 11, fascia 11, T=10.87 RH=26.80
# time 12, fascia 12, T=10.98 RH=23.89
# time 13, fascia 13, T=9.02 RH=25.14
# time 14, fascia 14, T=8.63 RH=26.75
# time 15, fascia 15, T=8.71 RH=33.64
# time 16, fascia 16, T=6.50 RH=40.16
# time 17, fascia 17, T=2.86 RH=35.43
# time 18, fascia 18, T=2.61 RH=42.28
# time 19, fascia 19, T=3.15 RH=37.07
# time 20, fascia 20, T=4.63 RH=36.78
# time 21, fascia 21, T=4.77 RH=35.85
# time 22, fascia 22, T=5.14 RH=45.01
# time 23, fascia 23, T=1.16 RH=51.60
# time 24, fascia 0, T=1.06 RH=54.87
# time 25, fascia 1, T=1.00 RH=46.72
# time 26, fascia 2, T=-0.85 RH=46.68
# time 27, fascia 3, T=-1.84 RH=47.64
# time 28, fascia 4, T=-1.67 RH=43.83
# time 29, fascia 5, T=-2.34 RH=45.99
# time 30, fascia 6, T=-2.43 RH=48.80
# time 31, fascia 7, T=-2.83 RH=39.30
# time 32, fascia 8, T=3.58 RH=27.14
# time 33, fascia 9, T=5.43 RH=29.35
# time 34, fascia 10, T=7.15 RH=24.78
# time 35, fascia 11, T=6.79 RH=26.80
# time 36, fascia 12, T=7.91 RH=26.75
# time 37, fascia 13, T=6.83 RH=27.95
# time 38, fascia 14, T=6.42 RH=32.26
# time 39, fascia 15, T=6.00 RH=44.46
# time 40, fascia 16, T=3.72 RH=45.50
# time 41, fascia 17, T=-0.44 RH=58.34
# time 42, fascia 18, T=-2.18 RH=64.52
# time 43, fascia 19, T=1.04 RH=52.64
# time 44, fascia 20, T=-0.71 RH=55.08
# time 45, fascia 21, T=-1.02 RH=66.49
# time 46, fascia 22, T=-1.53 RH=67.41
# time 47, fascia 23, T=0.37 RH=43.98
# time 48, fascia 0, T=0.30 RH=39.87
# time 49, fascia 1, T=0.28 RH=34.63
# time 50, fascia 2, T=0.60 RH=40.54
# time 51, fascia 3, T=2.64 RH=75.97
# time 52, fascia 4, T=2.58 RH=76.19
# time 53, fascia 5, T=3.51 RH=74.05
# time 54, fascia 6, T=2.95 RH=70.82
# time 55, fascia 7, T=3.30 RH=57.82
# time 56, fascia 8, T=5.96 RH=54.21
# time 57, fascia 9, T=7.15 RH=40.66
# time 58, fascia 10, T=7.15 RH=39.13
# time 59, fascia 11, T=6.79 RH=35.42
# time 60, fascia 12, T=7.15 RH=35.33
# time 61, fascia 13, T=6.10 RH=42.01
# time 62, fascia 14, T=5.68 RH=48.80
# time 63, fascia 15, T=4.65 RH=52.58
# time 64, fascia 16, T=3.72 RH=72.21
# time 65, fascia 17, T=1.54 RH=76.16
# time 66, fascia 18, T=0.55 RH=81.83
# time 67, fascia 19, T=1.04 RH=81.17
# time 68, fascia 20, T=0.05 RH=86.46
# time 69, fascia 21, T=-1.85 RH=86.91
# time 70, fascia 22, T=-2.36 RH=89.80
# time 71, fascia 23, T=-2.78 RH=82.06

# %% [markdown]
# #### Plot andamento di temperatura e umidità durante il time horizon T

# %%
def plot_weather_simulation(X_sim, f_t0=0):
    # --> X_sim: array (T, 2) con i dati simulati
    # --> f_t0: l'ora della fascia oraria di partenza (default 0)
    T = len(X_sim)
    time_steps = np.arange(T)
    
    # Calcoliamo le ore del giorno reali per ogni step
    hours_of_day = [(f_t0 + t) % 24 for t in range(T)]
    
    # Creiamo delle etichette stringa per l'asse x (es. "14:00")
    # Ne mostriamo una ogni 6 ore per non affollare il grafico
    labels = [f"{h:02d}:00" for h in hours_of_day]
    
    temps = X_sim[:, 0]
    humidity = X_sim[:, 1]
    
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8), sharex=True)
    
    # Plot Temperatura
    ax1.plot(time_steps, temps, color='tab:red', linewidth=2, label='Temperatura (°C)')
    ax1.set_ylabel('Temperatura (°C)')
    ax1.grid(True, linestyle='--', alpha=0.5)
    ax1.legend(loc='upper right')
    ax1.set_title(f'Evoluzione Temperatura e Umidità durante la simulazione (Inizio ore {f_t0:02d}:00)')
    
    # Plot Umidità
    ax2.plot(time_steps, humidity, color='tab:blue', linewidth=2, label='Umidità (%)')
    ax2.set_ylabel('Umidità Relativa (%)')
    ax2.set_xlabel('Ora del Giorno')
    ax2.grid(True, linestyle='--', alpha=0.5)
    ax2.legend(loc='upper right')
    
    # --- Gestione Asse X ---
    # Decidiamo ogni quante ore mettere un "tick" (es. ogni 6 ore)
    step_tick = 6 
    tick_indices = np.arange(0, T, step_tick)
    plt.xticks(tick_indices, [labels[i] for i in tick_indices])
    
    # Aggiungiamo linee verticali tratteggiate per indicare la mezzanotte (cambio giorno)
    for t in range(T):
        if (f_t0 + t) % 24 == 0:
            ax1.axvline(x=t, color='black', linestyle='-', alpha=0.3)
            ax2.axvline(x=t, color='black', linestyle='-', alpha=0.3)
            #ax1.text(t, ax1.get_ylim()[1], ' Giorno successivo', fontsize=8, verticalalignment='top')

    plt.tight_layout()
    plt.show()

# utilizzo dei risultatio della precedente simulazione
simulation_results=X_sim
#simulation_results=simulate_weather_transition(72)
plot_weather_simulation(simulation_results, f_t0=0)

# %% [markdown]
# ## Implementazione algoritmo DP
# ---

# %%
# funzione che esegue un singolo step dell'algoritmo di Dynamic Programming
@njit(parallel=True)
def dp_step(t, f_t, V_list, mu_star_list, temp_curr, humid_curr, depth_space, temp_next, humid_next, P_matrix_current, U_default):
    
    # Dimensioni
    n_T = len(temp_curr)
    n_RH = len(humid_curr)
    n_d = len(depth_space)
    
    n_T_next = len(temp_next)
    n_RH_next = len(humid_next)
    
    # Loop Parallelo sugli stati (Temperatura)
    for i in prange(n_T):
        for j in range(n_RH):
            for k in range(n_d):
                
                # --- 1. Definizione dello Stato Corrente ---
                T = temp_curr[i]
                RH = humid_curr[j]
                d = depth_space[k]
                
                # Creiamo l'array x_t per le funzioni helper (stage_cost, transition)
                x_t = np.array([T, RH, d], dtype=np.float32)
                
                # --- 2. Recupero Input Ammissibili ---
                # Usiamo la tua input_space (che ora deve ritornare un array 2D corretto)
                U_valid = input_space(T, RH, U_default,d,max_d)
                n_inputs = len(U_valid)
                
                # Variabili per trovare il minimo (logica argmin)
                best_total_cost = np.inf
                best_u = np.zeros(2, dtype=np.float32) # Placeholder
                
                # Indice linearizzato per la matrice P (meteo corrente)
                # Assumiamo che P sia organizzata: righe=stato_corrente, col=stato_next
                idx_curr_weather = i * n_RH + j 
                
                # --- 3. Loop sulle Azioni (u) ---
                for u_idx in range(n_inputs):
                    u = U_valid[u_idx]
                    
                    # A. Costo dello stadio corrente
                    cost_stage = stage_cost(x_t, u)

                    # B. Calcolo dinamico di E_cost_to_go
                    d_next = depth_transition(x_t, u)
                    
                    # Trova indice k_next (Searchsorted è O(log N), molto veloce)
                    k_next = np.searchsorted(depth_space, d_next)
                    
                    # Clipping indici per sicurezza
                    if k_next >= n_d: k_next = n_d - 1
                    if k_next < 0: k_next = 0
                    
                    # Calcolo del valore atteso iterando sui meteo futuri
                    E_cost_to_go = 0.0
                    
                    for i_next in range(n_T_next):
                        for j_next in range(n_RH_next):
                            
                            # Indice linearizzato meteo futuro
                            idx_next_weather = i_next * n_RH_next + j_next
                            
                            # Accesso diretto alla probabilità
                            prob = P_matrix_current[idx_curr_weather, idx_next_weather]
                            
                            if prob > 1e-8: # Piccola ottimizzazione per zeri
                                val_next = V_list[t+1, i_next, j_next, k_next]
                                E_cost_to_go += prob * val_next
                    
                    # C. Totale e Aggiornamento Minimo
                    total_val = cost_stage + E_cost_to_go
                    
                    if total_val < best_total_cost:
                        best_total_cost = total_val
                        best_u = u # Copia i valori perché u è un array numpy piccolo
                
                # --- 4. Salvataggio Risultati ---
                V_list[t, i, j, k] = best_total_cost
                mu_star_list[t, i, j, k, 0] = best_u[0]
                mu_star_list[t, i, j, k, 1] = best_u[1]

# DEFINIZIONE STRUTTURE DATI
# - ALLOCAZIONE ARRAY - state-value function e optimal policy
T=72 #lunghezza time horizon in ore
V_list=np.zeros((T+1,n_T,n_RH,n_d),dtype=np.float32) #lista di cost value functions, una per ogni istenate di tempo
mu_star_list=np.zeros((T,n_T,n_RH,n_d,2),dtype=np.float32)# policy da trovare, per ogni fascia oraria
print(V_list[0].shape)
print(mu_star_list[0].shape)

# - INIZIALIZZAZIONE ARRAY V_list
# loop over all the possible states
target_d_idx=np.where(depth_space == d_target)[0][0] #indice di profondità da raggiungere
for i in range(n_T):
    for j in range(n_RH):
        for k in range(n_d): 
            if k<target_d_idx:
                V_list[T,i,j,k]=penalization_cost

@njit
def run_dp_algorithm(T,V,optimal_policy):    
    # ITERAZIONI
    # loop over all the time instants in [T-1,...,0]
    for t in range(T-1,-1,-1): 
        print(f"Processing time {t}")
        f_t=t%24 #fascia a cui appartiene l'istante t
        # Determinazione array meteo corrente e prossimo
        temp_curr = temp_val[f_t]
        humid_curr = humid_val[f_t]
        # - se siamo all'ultima ora, il "next" è l'ora 0
        if f_t == 23: f_t_next=0
        else: f_t_next=f_t+1
        temp_next = temp_val[f_t_next]
        humid_next = humid_val[f_t_next]
        # Esecuzione singolo step di dp
        dp_step(t,f_t,V,optimal_policy,temp_curr,humid_curr,depth_space,temp_next,humid_next,P_list[f_t],U_default)
# Out:
# (30, 30, 201)
# (30, 30, 201, 2)

# %% [markdown]
# ## Esecuzione dell'algoritmo
# ---
# L'algoritmo di DP viene eseguito se non è presente già il file con la policy ottimale.
# In questo caso la policy viene caricata come numpy array.

# %%
filename = "optimal_policy.npy"
# Controlla se il file con la policy ottimale esiste o meno
if not os.path.exists(filename):
    print(f"File \"{filename}\" non trovato. Eseguo l'algoritmo di Dynamic Programming...")

    # Esecuzione algoritmo di DP
    run_dp_algorithm(T,V_list,mu_star_list)
    
    # Salvataggio della policy su file
    np.save(filename, mu_star_list)
    optimal_policy = mu_star_list
    print("Calcolo completato e file salvato.")
else:
    # Se il file esiste, viene caricato
    print(f"File \"{filename}\" trovato! Caricamento della policy ottimale in corso...")
    optimal_policy = np.load(filename)
# Out:
# File "optimal_policy.npy" non trovato. Eseguo l'algoritmo di Dynamic Programming...
# Processing time 71
# Processing time 70
# Processing time 69
# Processing time 68
# Processing time 67
# Processing time 66
# Processing time 65
# Processing time 64
# Processing time 63
# Processing time 62
# Processing time 61
# Processing time 60
# Processing time 59
# Processing time 58
# Processing time 57
# Processing time 56
# Processing time 55
# Processing time 54
# Processing time 53
# Processing time 52
# Processing time 51
# Processing time 50
# Processing time 49
# Processing time 48
# Processing time 47
# Processing time 46
# Processing time 45
# Processing time 44
# Processing time 43
# Processing time 42
# Processing time 41
# Processing time 40
# Processing time 39
# Processing time 38
# Processing time 37
# Processing time 36
# Processing time 35
# Processing time 34
# Processing time 33
# Processing time 32
# Processing time 31
# Processing time 30
# Processing time 29
# Processing time 28
# Processing time 27
# Processing time 26
# Processing time 25
# Processing time 24
# Processing time 23
# Processing time 22
# Processing time 21
# Processing time 20
# Processing time 19
# Processing time 18
# Processing time 17
# Processing time 16
# Processing time 15
# Processing time 14
# Processing time 13
# Processing time 12
# Processing time 11
# Processing time 10
# Processing time 9
# Processing time 8
# Processing time 7
# Processing time 6
# Processing time 5
# Processing time 4
# Processing time 3
# Processing time 2
# Processing time 1
# Processing time 0
# Calcolo completato e file salvato.

# %% [markdown]
# ## Simulazione del sistema
# ---

# %% [markdown]
# ### Funzione per simulare il sistema con una determinata policy

# %%
# - funzione per la simulazione del sistema 
def simulate(T,d0,policy,print_enabled=False):
    # --> T: lunghezza time horizon
    # --> d0: profondità della neve all'inizio del time horizon
    # --> policy: policy utilizzata per la selesione dell'ingresso del sistema
    X_sim=np.empty((T,3)) #lista degli stati visitati dal sistema durante la simulazione
    t0=0
    f_t0=t0%24 #fascia oraria a cui appartiene t0
    x_0=get_initial_state(f_t0,d0) 
    # inizializzazione
    T_idx = np.searchsorted(temp_val[f_t0], x_0[0])
    RH_idx = np.searchsorted(humid_val[f_t0], x_0[1])
    d_idx = np.searchsorted(depth_space, x_0[2])
    u_t0=policy[t0,T_idx,RH_idx,d_idx,:]
    total_cost = stage_cost(x_0,u_t0)
    # iterazione
    x_t=x_0
    u_t=u_t0
    f_t=f_t0
    for t in range(T):
        if print_enabled: print(f"time {t}, fascia {f_t}, T={x_t[0]:.2f} RH={x_t[1]:.2f}% d={x_t[2]:.2f}")
        next_T, next_RH = weather_transition(x_t,f_t)
        next_d = depth_transition(x_t,u_t)
        x_tp1 = np.array([next_T,next_RH,next_d],dtype=np.float32)
        X_sim[t]=x_tp1
        x_t=x_tp1
        f_t=(t+1)%24
        if t<=70:
            if print_enabled: print(f"--> ingresso: air_flow={u_t[0]:.2f} water_flow=={u_t[1]:.2f}\n")
            T_next_idx = np.searchsorted(temp_val[f_t], x_t[0])
            RH_next_idx = np.searchsorted(humid_val[f_t], x_t[1])
            d_next_idx = np.searchsorted(depth_space, x_t[2])
            u_t=policy[t+1,T_next_idx,RH_next_idx,d_next_idx,:]
            total_cost += stage_cost(x_t, u_t)
        else:
            total_cost += terminal_cost(x_t)
    if print_enabled: print(f"Costo totale: {total_cost:.2f}")
    return X_sim, total_cost

# %% [markdown]
# ### Funzione per plottare l'evoluzione della profondità della neve

# %%
def plot_snow_depth(X_sim,f_t0=0):
    # --> X_sim: array (T, 3) restituito dalla funzione simulate
    # --> f_t0: fascia di inizio della simulazione
    T = len(X_sim)
    time_steps = np.arange(T)
    
    # Estraiamo la profondità della neve (terza colonna, indice 2)
    snow_depth = X_sim[:, 2]
    
    # Calcolo delle ore per l'asse X (come fatto per il meteo)
    hours_of_day = [(f_t0 + t) % 24 for t in range(T)]
    labels = [f"{h:02d}:00" for h in hours_of_day]
    
    plt.figure(figsize=(12, 6))
    
    # Plot della profondità simulata
    plt.plot(time_steps, snow_depth, color='tab:blue', linewidth=2.5, label='Profondità neve (d)')
    
    # Riga orizzontale del Target
    plt.axhline(y=d_target, color='tab:red', linestyle='--', linewidth=2, label=f'Target (d={d_target})')
    
    # Formattazione grafica
    plt.title('Evoluzione della profondità della neve durante la simulazione', fontsize=14)
    plt.ylabel('Profondità (m)', fontsize=12) # o la tua unità di misura
    plt.xlabel('Ora del Giorno', fontsize=12)
    
    # Gestione dei Tick dell'asse X (uno ogni 6 ore)
    step_tick = 6
    tick_indices = np.arange(0, T, step_tick)
    plt.xticks(tick_indices, [labels[i] for i in tick_indices])
    
    # Linee verticali per la mezzanotte
    for t in range(T):
        if (f_t0 + t) % 24 == 0:
            plt.axvline(x=t, color='black', linestyle='-', alpha=0.2)

    plt.legend(loc='best')
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Simulazione optimal policy
# ---

# %% [markdown]
# Singola simulazione del sistema con la policy ottimale e plot dell'evoluzione dello stato del sistema nel tempo.

# %%
T_horiz = 72
simulation_results=simulate(T_horiz,d0=0,policy=optimal_policy,print_enabled=True)[0]
plot_weather_simulation(simulation_results, f_t0=0)
plot_snow_depth(simulation_results,f_t0=0)
# Out:
# time 0, fascia 0, T=7.46 RH=84.60% d=0.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 1, fascia 1, T=-6.57 RH=84.88% d=0.00
# --> ingresso: air_flow=6.00 water_flow==4.60
#
# time 2, fascia 2, T=-6.17 RH=87.82% d=9.50
# --> ingresso: air_flow=6.00 water_flow==4.60
#
# time 3, fascia 3, T=-5.95 RH=89.60% d=18.00
# --> ingresso: air_flow=6.00 water_flow==4.60
#
# time 4, fascia 4, T=-7.07 RH=86.87% d=26.00
# --> ingresso: air_flow=6.00 water_flow==4.60
#
# time 5, fascia 5, T=-6.62 RH=84.82% d=36.50
# --> ingresso: air_flow=6.00 water_flow==4.40
#
# time 6, fascia 6, T=-6.88 RH=78.37% d=46.00
# --> ingresso: air_flow=6.00 water_flow==4.60
#
# time 7, fascia 7, T=-6.47 RH=75.71% d=57.00
# --> ingresso: air_flow=6.00 water_flow==4.60
#
# time 8, fascia 8, T=-5.55 RH=68.40% d=67.50
# --> ingresso: air_flow=6.00 water_flow==4.60
#
# time 9, fascia 9, T=-3.54 RH=51.50% d=77.00
# --> ingresso: air_flow=6.00 water_flow==4.60
#
# time 10, fascia 10, T=-2.33 RH=32.18% d=84.50
# --> ingresso: air_flow=6.00 water_flow==4.60
#
# time 11, fascia 11, T=-1.20 RH=30.52% d=91.00
# --> ingresso: air_flow=6.00 water_flow==4.60
#
# time 12, fascia 12, T=-0.57 RH=21.05% d=96.00
# --> ingresso: air_flow=6.00 water_flow==4.00
#
# time 13, fascia 13, T=0.26 RH=21.03% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 14, fascia 14, T=0.99 RH=25.14% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 15, fascia 15, T=-0.24 RH=29.51% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 16, fascia 16, T=-1.45 RH=30.93% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 17, fascia 17, T=-2.52 RH=26.80% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 18, fascia 18, T=-3.73 RH=43.07% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 19, fascia 19, T=-4.24 RH=34.87% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 20, fascia 20, T=-5.30 RH=26.70% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 21, fascia 21, T=-5.28 RH=28.93% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 22, fascia 22, T=-6.82 RH=33.30% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 23, fascia 23, T=-8.20 RH=32.57% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 24, fascia 0, T=-12.23 RH=76.99% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 25, fascia 1, T=-12.67 RH=77.38% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 26, fascia 2, T=-12.62 RH=80.57% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 27, fascia 3, T=-12.50 RH=81.43% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 28, fascia 4, T=-13.05 RH=82.51% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 29, fascia 5, T=-12.99 RH=82.67% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 30, fascia 6, T=-12.07 RH=84.85% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 31, fascia 7, T=-11.18 RH=75.71% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 32, fascia 8, T=-8.95 RH=92.22% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 33, fascia 9, T=-7.50 RH=89.41% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 34, fascia 10, T=-4.91 RH=85.89% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 35, fascia 11, T=-5.37 RH=73.59% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 36, fascia 12, T=-4.65 RH=72.79% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 37, fascia 13, T=-5.86 RH=63.95% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 38, fascia 14, T=-4.12 RH=72.93% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 39, fascia 15, T=-6.15 RH=81.86% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 40, fascia 16, T=-7.55 RH=87.77% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 41, fascia 17, T=-10.15 RH=93.58% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 42, fascia 18, T=-11.64 RH=93.98% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 43, fascia 19, T=-11.77 RH=94.18% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 44, fascia 20, T=-10.23 RH=94.14% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 45, fascia 21, T=-10.61 RH=94.30% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 46, fascia 22, T=-9.31 RH=94.57% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 47, fascia 23, T=-9.87 RH=92.29% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 48, fascia 0, T=-6.72 RH=92.22% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 49, fascia 1, T=-6.57 RH=92.38% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 50, fascia 2, T=-6.17 RH=92.66% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 51, fascia 3, T=-6.68 RH=91.65% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 52, fascia 4, T=-7.07 RH=91.23% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 53, fascia 5, T=-8.04 RH=91.30% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 54, fascia 6, T=-7.53 RH=91.32% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 55, fascia 7, T=-7.81 RH=90.39% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 56, fascia 8, T=-7.59 RH=92.22% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 57, fascia 9, T=-5.12 RH=92.11% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 58, fascia 10, T=-3.19 RH=94.37% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 59, fascia 11, T=-0.36 RH=93.69% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 60, fascia 12, T=1.07 RH=92.90% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 61, fascia 13, T=1.03 RH=92.56% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 62, fascia 14, T=0.99 RH=92.60% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 63, fascia 15, T=-0.24 RH=92.88% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 64, fascia 16, T=-0.78 RH=93.19% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 65, fascia 17, T=-1.83 RH=93.58% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 66, fascia 18, T=-3.07 RH=93.98% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 67, fascia 19, T=-3.55 RH=94.18% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 68, fascia 20, T=-4.60 RH=94.14% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 69, fascia 21, T=-5.28 RH=94.30% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 70, fascia 22, T=-5.17 RH=94.57% d=100.00
# --> ingresso: air_flow=0.00 water_flow==0.00
#
# time 71, fascia 23, T=-4.03 RH=94.78% d=100.00
# Costo totale: 481.32

# %% [markdown]
# Effettuazione di multiple simulazioni e plot dei risultati ottenuti.

# %%
num_simulations = int(1e4)
total_costs_vector = np.empty(num_simulations)

def run_simulations(total_costs_vector, num_simulations):
    for i in range(num_simulations):
        total_costs_vector[i] = simulate(72,0,optimal_policy)[1]

run_simulations(total_costs_vector, num_simulations)

plt.hist(total_costs_vector, bins=100, alpha=0.7, edgecolor="black")
plt.xlabel("Costo totale")
plt.ylabel("Frequenza")
plt.title(f"Istogramma con {num_simulations} simulazioni")
plt.grid(True)
plt.show()

# %%
print(np.mean(total_costs_vector))
# Out:
# 870.6843472968718

# %% [markdown]
# ## Definizione policy euristica
# ---

# %%
def heuristic_policy(x_t):
    temp_t, hum_t, d_t = x_t[0], x_t[1], x_t[2]
    T_wb_soglia= -2.5 #°C
    wb_t = wet_bulb_temperature(temp_t, hum_t)
    if wb_t < T_wb_soglia:
        # Possiamo sparare neve
        if d_t < d_target:
            # Si spara il più possibile
            a_f = 27.0 # m^3/h
            w_f = 4.5 # m^3/h
            u_t = [a_f, w_f]
        else:
            # Siamo già a profondità target anche se potremmo sparare
            u_t = [0.0, 0.0]
    else:
        # Non possiamo sparare
        u_t = [0.0, 0.0]
    return u_t

# %% [markdown]
# ## Simulazione policy euristica
# ---

# %%
# - funzione per la simulazione del sistema 
def simulate_heuristic(T,d0,print_enabled=False):
    # --> T: lunghezza time horizon
    # --> d0: profondità della neve all'inizio del time horizon
    # --> policy: policy utilizzata per la selesione dell'ingresso del sistema
    X_sim=np.empty((T,3)) #lista degli stati visitati dal sistema durante la simulazione
    t0=0
    f_t0=t0%24 #fascia oraria a cui appartiene t0
    x_0=get_initial_state(f_t0,d0) 
    # inizializzazione
    u_t0=heuristic_policy(x_0)
    total_cost = stage_cost(x_0,u_t0)
    # iterazione
    x_t=x_0
    u_t=u_t0
    f_t=f_t0
    for t in range(T):
        if print_enabled: print(f"time {t}, fascia {f_t}, T={x_t[0]:.2f} RH={x_t[1]:.2f}% d={x_t[2]:.2f}")
        next_T, next_RH = weather_transition(x_t,f_t)
        next_d = depth_transition(x_t,u_t)
        x_tp1 = np.array([next_T,next_RH,next_d],dtype=np.float32)
        X_sim[t]=x_tp1
        x_t=x_tp1
        f_t=(t+1)%24
        if t<=70:
            if print_enabled: print(f"--> ingresso: air_flow={u_t[0]:.2f} water_flow=={u_t[1]:.2f}\n")
            u_t=heuristic_policy(x_t)
            total_cost += stage_cost(x_t, u_t)
        else:
            total_cost += terminal_cost(x_t)
    if print_enabled: print(f"Costo totale: {total_cost:.2f}")
    return X_sim, total_cost

# %% [markdown]
# # Esecuzione simulazioni

# %%
num_simulations = int(1e4)
total_costs_vector = np.empty(num_simulations)

def run_simulations(total_costs_vector, num_simulations):
    for i in range(num_simulations):
        total_costs_vector[i] = simulate_heuristic(72,0)[1]

run_simulations(total_costs_vector, num_simulations)

plt.hist(total_costs_vector, bins=100, alpha=0.7, edgecolor="black")
plt.xlabel("Costo totale")
plt.ylabel("Frequenza")
plt.title(f"Istogramma con {num_simulations} simulazioni")
plt.grid(True)
plt.show()

# %%
print(np.mean(total_costs_vector))
# Out:
# 1066.38740125
