# %% [markdown]
# # Sistema di produzione di neve artificiale
# ---

# %% [markdown]
# ## Formulazione del problema

# %% [markdown]
# - orizzonte temporale: $t=0,1,...T$, $T = 72$ ore considerando un time step orario
# - stato $x_t: (temperatura\_ora\_t,umidità\_ora\_t,livello\_neve\_ora\_t) = (T_t,RH_t,d_t) = (i,j,k)$
# - spazio degli stati $x_t \in X_t=\{(i,j,k): i=1,...,50, j=1,...,50, k=1,...,n\}$
#     - $T_t \in\{T_1,...,T_{50}\}_t$ con valori diversi da ora in ora
#         - $T_t$ variabile aleatoria discreta con pmf $P(T_t=T_i)_t$
#     - $RH_t \in\{RH_1,...,RH_{50}\}_t$ con valori diversi da ora in ora
#         - $RH_t$ variabile aleatoria discreta con pmf $P(RH_t=RH_i)_t$
#     - $d_t \in D=\{0,...,max_d\}, |D|=n$
# - ingresso $u_t=(af_t,wf_t)$
#     - $af_t$: flusso di aria iniettato nella macchina sparaneve nell'ora t $[m^3/h]$
#     - $wf_t$: flusso di acqua iniettato nella macchina sparaneve nell'ora t $[m^3/h]$
# - spazio degli ingressi $u_t \in U=
#     \begin{cases}
#     \{(0,0)\} & \text{se } \text{la } \text{neve } \text{non } \text{può } \text{essere } \text{prodotta } \text{dati } (T_t,RH_t) \\
#     \{(min_{af},min_{wf}),...,(max_{af},max_{wf})\} & \text{altrimenti }
#     \end{cases}$
#     - $min_{wf} = 0.6 [m^3/h], max_{wf} = [3.6,5.4] [m^3/h]$
#         - step di discretizzazione: $0.2$
#     - $min_{af} = 6 [m^3/h], max_{af} = 27 [m^3/h]$
#         - step di dicretizzazione: $1$
#     - la neve non può essere prodotta se la temperatura del bulbo umido è superiore alla soglia operativa $T_{wb,soglia} = -2.5 °C$
# - matrice di transizione per le componenti di temperatura e umidità dello stato
#     - $P((T_{t+1}=i,RH_{t+1}=j)|(T_{t}=i',RH_{t}=j'))=P(T_{t+1}=i|T_t=i')_{t+1}*P(RH_{t+1}=j|RH_t=j')_{t+1}$
# - funzione di transizione per la componente "livello_neve" dello stato
#     - $d_{t+1}=d_t+Neve\_prodotta(x_t,u_t)-Neve\_fusa(x_t)$
#     - valore da approssimare al valore discreto più vicino assunto da $d_t$
# - funzione per determinare la neve prodotta in un time step in $m^3$
#     - $Neve\_prodotta(T_t,RH_t,af_t,wf_t)=k(T_t,RH_t)*min(af_t,wf_t)$
#     - $k=\alpha * max(0,T_{wb,soglia}-T_{wb})$ coefficiente di efficienza
#     - $\alpha:$ coefficiente calibrato $\in [0.4,1]$
#     - $T_{wb,soglia} = -2.5 °C$: soglia (wet-bulb) operativa del generatore
#     - $T_{wb} ≈ T_t ⋅arctan(0.151977⋅(RH_t+8.313659)^{0.5})+arctan(T_t+RH_t)-arctan(RH_t−1.676331)
# +0.00391838⋅RH^{1.5}⋅arctan(0.023101⋅RH)−4.686035$
#         - dove $T_t$ in $°C$ e $RH_t$ in percentuale
# - funzione per determinare la neve fusa in un time step in $m^3$
#     - $Neve\_fusa(x_t)= (DDF/(1000*24)) * max(T_{avg}-T_0,0) * A$
#         - $DDF = degree-day-factor (mm/°C/giorno)$ (tipicamente 1–10 mm)
#         - $T_{avg} = temperatura-media °C$
#         - $T_0 = soglia (≈°C)$
#         - $A = area (m^2)$
# - stage cost $g(u_t):$ deterministico, tempo-invariante
#     - $g(u_t)=prezzo\_energia*(E_{ventola}+E_{compressore}(u_t)+E_{pompa}(u_t))$
#     - $prezzo\_energia$ in kWh
#     - $E_{ventola}=18.5 kWh$ costante
#     - $E_{compressore}(u_t)= e * af_t * 60$
#         - $e=6.2 [kW/(m^3/min)]$
#         - $af_t [m^3/h]$
#     - $E_{pompa}(u_t)=k_{pump}*wf_t$
#         - $k_{pump}=3.5 [kWh/m^3]$
#         - $af_t [m^3/h]$
# - Terminal cost $g_T(x_T)$:
#     - $g_T((i,j,k)) = \begin{cases} 0 & \text{if } k = n \\ \infty & \text{if } k \neq n \end{cases}$
#     - costo infinito se non viene prodotta $max_d [m^3]$ di neve al termine dell'orizzonte temporale

# %% [markdown]
# ## Formulazione del problema
# ---

# %% [markdown]
# ### Importazione moduli

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import json
import math 
from functions import *

# %% [markdown]
# ### Caricamento dati meteorologici da file

# %%
# CARICAMENTO DATI temperatura e umidità DA FILE JSON
with open("pmf_temperature.json", "r", encoding="utf-8") as f1:
    temperature = json.load(f1)

with open("pmf_humidity.json", "r", encoding="utf-8") as f2:
    humidity = json.load(f2)

# conversione dei dizionari in liste
#temperatura
temp_val=[] #valori discreti per fasce orarie
temp_pmf=[] #pmf per fasce orarie
for fasce,dict_val in temperature.items():
    temp_val.append(np.array(dict_val['values'],dtype=np.float32))
    temp_pmf.append(np.array(dict_val['pmf'],dtype=np.float32))
    
#umidità
humid_val=[] #valori discreti per fasce orarie
humid_pmf=[] #pmf per fasce orarie
for fasce,dict_val in humidity.items():
    humid_val.append(np.array(dict_val['values'],dtype=np.float32))
    humid_pmf.append(np.array(dict_val['pmf'],dtype=np.float32))

#caricamento delle matrici delle probabilità condizionate da file
P_T_list = load_transition_matrices("transition_T.json") #lista di matrici P_T, una per ogni fascia oraria
P_RH_list = load_transition_matrices("transition_RH.json") #lista di matrici P_RH, una per ogni fascia oraria

print("Caricate", len(P_T_list), "matrici di transizione T")
print("Caricate", len(P_RH_list), "matrici di transizione RH")
#print("Dimensione prima matrice T:", P_T_list[0].shape)
#print(P_T_list[0])
# Out:
# Caricate 24 matrici di transizione T
# Caricate 24 matrici di transizione RH

# %% [markdown]
# ### Parametri del problema

# %%
n_fasce=24 #fasce orarie
n_T = temp_val[0].shape[0] #numero di intervalli di discretizzazione di temperatura
n_RH = humid_val[0].shape[0] #numero di intervalli di discretizzazione di umidità
n_T_RH = n_T * n_RH #numero di possibili combinazioni di temperatura e umidità per fascia oraria
max_d=100 #profondità massima della neve
step_d=0.5 #step di discretizzazione della profondità della neve
#flusso di aria minimo e massimo in ingresso allo sparaneve
min_af=6
max_af=27
af_step=1 #step di discretizzazione del flusso di aria
#flusso di acqua minimo e massimo in ingresso allo sparaneve
min_wf=0.6
max_wf=4.5 #[3.6,5.4]
wf_step=0.2 #step di discretizzazione del flusso di acqua
d_target=50 #livello di neve che deve essere raggiunta in m^3

# %% [markdown]
# ### Formulazione del problema

# %%
# Definizione dello spazio dei valori discreti della profondità della neve
depth_space=np.arange(0,max_d+step_d,step_d,dtype=np.float32)
n_d=depth_space.shape[0] ##numero di intervalli di discretizzazione della profondità della neve

# Spazio degli stati
state_space=[]
n_states=n_T*n_RH*n_d #numero di stati per fascia oraria
# - definizione di uno spazio degli stati per ogni fascia oraria
for f in range(n_fasce):
    X=np.empty((n_T,n_RH,n_d,3),dtype=np.float32)
    for i,T in enumerate(temp_val[f]):
        for j,RH in enumerate(humid_val[f]):
            for k,d in enumerate(depth_space):            
                X[i,j,k]=[T,RH,d]
    state_space.append(X)

# Spazio degli ingressi
af_val=np.arange(min_af,max_af+af_step,af_step,dtype=np.float32)
af_n_val=af_val.shape[0]
wf_val=np.arange(min_wf,max_wf+wf_step,wf_step,dtype=np.float32)
wf_n_val=wf_val.shape[0]
U_default=np.empty((af_n_val,wf_n_val,2),dtype=np.float32)
for i,af in enumerate(af_val):
    for j,wf in enumerate(wf_val):
        U_default[i,j]=[af,wf]
#U=input_space(-1,90,min_af, max_af, min_wf, max_wf, af_step, wf_step)

# Calcolo matrici P_t di transizione delle componenti temperatura e umidità dello stato
# --> P_list conterrà una matrice di transizione per fascia oraria
P_list = []

for f in range(n_fasce):
    P_T = P_T_list[f] #matrice delle probabilità condizionate della temperatura relativa alla fascia f
    P_RH = P_RH_list[f] #matrice delle probabilità condizionate dell'umidità relativa alla fascia f
    P_list.append(build_joint_transition(P_T, P_RH))

print(P_list[0].shape)

# Dinamica del sistema
# - funzione che restituisce uno stato iniziale secondo le distribuzioni di temperatura e umidità nella fascia oraria iniziale
# - e secondo la profondità iniziale della neve passata come parametro
def get_initial_state(f_t0,d0):
    # --> f_t0: fascia oraria dell'istante di tempo iniziale t0 del time horizon
    # da aggiungere il controllo della fascia oraria
    pmf_T_t0=temp_pmf[f_t0] # pmf temperatura nella fascia f_t0
    pmf_RH_t0=humid_pmf[f_t0] # pmf umidità nella fascia f_t0
    T0=np.random.choice(temp_val[f_t0], p=pmf_T_t0) # estrazione di un campione di temperatura dalla relativa pmf
    RH0=np.random.choice(humid_val[f_t0], p=pmf_RH_t0) # estrazione di un campione di umidità dalla relativa pmf
    x_0=[T0,RH0,d0]
    return x_0
print(get_initial_state(0,depth_space[-1]))

# - funzione di transizione per la componente 'profondità_neve' dello stato (deterministica)
def depth_transition(x_t,u_t):
    T_t=x_t[0]
    RH_t=x_t[1]
    d_t=x_t[2]
    af_t=u_t[0]
    wf_t=u_t[1]
    # profondità della neve al prossimo time step (fascia oraria)
    d_next=d_t+snow_produced(T_t,RH_t,af_t,wf_t)-snow_melted(T_t,RH_t)
    if d_next<0:
        d_next_discretized=np.float32(0)
    else: # arrotondamento al campione discreto più vicino
        d_next_discretized=depth_space[np.argmin(np.abs(depth_space-d_next))]
    return d_next_discretized

x_t=[-13.1757,30.776318339275747,5]
u_t=[10,3]
print(depth_transition(x_t,u_t))

# - evoluzione di uno step per temperatura e umidità, secondo la matrice di transizione realtiva alla fascia f
def weather_transition(x_t,f): #da aggiungere la rotazione delle fasce --> 23 - 0
    T_t=x_t[0]
    RH_t=x_t[1]
    # matrice di transizione relativa alla fascia f
    P_f = P_list[f] 
    # conversione stato in indice
    state_idx = state_to_index(T_t,RH_t,temp_val[f],humid_val[f])
    # estrazione di un campione secondo la pmf condizionata allo stato corrente, presente nella matrice P_f
    next_state_idx = np.random.choice(np.arange(0,n_T_RH,1), p=P_f[state_idx]) 
    # conversione indice ottenuto in stato
    if f<23:
        next_T, next_RH = index_to_state(next_state_idx,temp_val[f+1],humid_val[f+1])
    else: #siamo nell'ultima fascia oraria, i prossimi valori da considerare per temperatura e umidità vengono presi dalla fascia 0
        next_T, next_RH = index_to_state(next_state_idx,temp_val[0],humid_val[0])
    return next_T, next_RH
print(weather_transition(x_t,0))

# - simulazione del sistema per un singolo time horizon t=0,...,T
def simulate(T,d0):
    # --> T: lunghezza time horizon
    # --> d0: profondità della neve all'inizio del time horizon
    X_sim=[] #lista degli stati visitati dal sistema durante la simulazione
    f_t0=0 #fascia oraria a cui appartiene t0
    x_0=get_initial_state(f_t0,d0) 
    # inizializzazione
    u_t=[0,0]
    x_t=x_0
    f_t=f_t0
    # iterazione
    for t in range(T):
        next_T, next_RH = weather_transition(x_t,f_t)
        next_d = depth_transition(x_t,u_t)
        x_tp1 = [next_T,next_RH,next_d]
        X_sim.append(x_tp1)
        print("time "+str(t)+", fascia "+str(f_t)+", stato: "+str(x_tp1))
        x_t=x_tp1
        f_t=(t+1)%24

simulate(72,depth_space[-1])


def stage_cost(x_t,u_t):
    T_t=x_t[0]
    RH_t=x_t[1]
    if u_t in input_space(T_t,RH_t,U_default):
        af_t=u_t[0]
        wf_t=u_t[1]
        energy_price=0.25 #€/kWh
        E_fan=18.5 #kWh
        e=6.2 #kW/(m^3/min)
        E_compressor=e*af_t #kWh
        k_pump=2.7 #kWh/m^3 ~0.2–2.7 kWh/m³
        E_pump=k_pump*wf_t #kWh 
        return energy_price*(E_fan+E_compressor+E_pump)
    else:
        print("Invalid input value given the current state... the stage cost cannot be computed")
        return -1

def terminal_cost(x_T):
    d_t=x_T[2]
    if d_t!=d_target:
        return np.inf
    else:
        return 0
# Out:
# (2500, 2500)
# [np.float32(0.5297), np.float32(64.29059), np.float32(100.0)]
# 30.0
# (np.float32(-13.7427), np.float32(33.364006))
# time 0, fascia 0, stato: [np.float32(-6.4179), np.float32(48.36825), np.float32(100.0)]
# time 1, fascia 1, stato: [np.float32(-6.31295), np.float32(47.198624), np.float32(100.0)]
# time 2, fascia 2, stato: [np.float32(-7.551625), np.float32(45.449577), np.float32(100.0)]
# time 3, fascia 3, stato: [np.float32(-7.5194), np.float32(44.58388), np.float32(100.0)]
# time 4, fascia 4, stato: [np.float32(-7.8964), np.float32(67.132545), np.float32(100.0)]
# time 5, fascia 5, stato: [np.float32(-7.915725), np.float32(67.144875), np.float32(100.0)]
# time 6, fascia 6, stato: [np.float32(-8.3503), np.float32(70.330925), np.float32(100.0)]
# time 7, fascia 7, stato: [np.float32(-6.908125), np.float32(71.051125), np.float32(100.0)]
# time 8, fascia 8, stato: [np.float32(-6.54895), np.float32(68.8309), np.float32(100.0)]
# time 9, fascia 9, stato: [np.float32(-4.22305), np.float32(63.836857), np.float32(100.0)]
# time 10, fascia 10, stato: [np.float32(-4.5325), np.float32(66.12644), np.float32(100.0)]
# time 11, fascia 11, stato: [np.float32(-3.836875), np.float32(65.31245), np.float32(100.0)]
# time 12, fascia 12, stato: [np.float32(-3.7184), np.float32(61.65758), np.float32(100.0)]
# time 13, fascia 13, stato: [np.float32(-3.97305), np.float32(60.559135), np.float32(100.0)]
# time 14, fascia 14, stato: [np.float32(-4.08075), np.float32(63.125698), np.float32(100.0)]
# time 15, fascia 15, stato: [np.float32(-4.977675), np.float32(67.20213), np.float32(100.0)]
# time 16, fascia 16, stato: [np.float32(-5.57015), np.float32(72.74827), np.float32(100.0)]
# time 17, fascia 17, stato: [np.float32(-6.23665), np.float32(80.23041), np.float32(100.0)]
# time 18, fascia 18, stato: [np.float32(-6.564725), np.float32(74.905754), np.float32(100.0)]
# time 19, fascia 19, stato: [np.float32(-6.56615), np.float32(64.56804), np.float32(100.0)]
# time 20, fascia 20, stato: [np.float32(-6.347125), np.float32(59.788063), np.float32(100.0)]
# time 21, fascia 21, stato: [np.float32(-6.989), np.float32(59.340855), np.float32(100.0)]
# time 22, fascia 22, stato: [np.float32(-4.19735), np.float32(60.438263), np.float32(100.0)]
# time 23, fascia 23, stato: [np.float32(-15.5387), np.float32(62.767216), np.float32(100.0)]
# time 24, fascia 0, stato: [np.float32(-15.1161), np.float32(61.87207), np.float32(100.0)]
# time 25, fascia 1, stato: [np.float32(-14.91495), np.float32(61.706295), np.float32(100.0)]
# time 26, fascia 2, stato: [np.float32(-14.539625), np.float32(60.167717), np.float32(100.0)]
# time 27, fascia 3, stato: [np.float32(-13.797), np.float32(55.04565), np.float32(100.0)]
# time 28, fascia 4, stato: [np.float32(-12.1444), np.float32(60.660088), np.float32(100.0)]
# time 29, fascia 5, stato: [np.float32(-12.198575), np.float32(63.258945), np.float32(100.0)]
# time 30, fascia 6, stato: [np.float32(-11.1755), np.float32(58.58688), np.float32(100.0)]
# time 31, fascia 7, stato: [np.float32(-8.949375), np.float32(51.99785), np.float32(100.0)]
# time 32, fascia 8, stato: [np.float32(-5.12425), np.float32(29.8445), np.float32(100.0)]
# time 33, fascia 9, stato: [np.float32(-3.18925), np.float32(28.220602), np.float32(100.0)]
# time 34, fascia 10, stato: [np.float32(-2.5301), np.float32(40.281826), np.float32(100.0)]
# time 35, fascia 11, stato: [np.float32(-2.366125), np.float32(35.996784), np.float32(100.0)]
# time 36, fascia 12, stato: [np.float32(-2.3408), np.float32(35.90648), np.float32(100.0)]
# time 37, fascia 13, stato: [np.float32(-2.22065), np.float32(35.259987), np.float32(100.0)]
# time 38, fascia 14, stato: [np.float32(-2.75025), np.float32(41.633305), np.float32(100.0)]
# time 39, fascia 15, stato: [np.float32(-3.757725), np.float32(44.464073), np.float32(100.0)]
# time 40, fascia 16, stato: [np.float32(-3.90575), np.float32(64.73453), np.float32(100.0)]
# time 41, fascia 17, stato: [np.float32(-4.65545), np.float32(78.703094), np.float32(100.0)]
# time 42, fascia 18, stato: [np.float32(-5.743425), np.float32(77.87173), np.float32(100.0)]
# time 43, fascia 19, stato: [np.float32(-5.72155), np.float32(87.91122), np.float32(100.0)]
# time 44, fascia 20, stato: [np.float32(-5.889875), np.float32(88.02658), np.float32(100.0)]
# time 45, fascia 21, stato: [np.float32(-5.498), np.float32(88.44331), np.float32(100.0)]
# time 46, fascia 22, stato: [np.float32(-5.69825), np.float32(88.806435), np.float32(100.0)]
# time 47, fascia 23, stato: [np.float32(-6.0867), np.float32(87.141235), np.float32(100.0)]
# time 48, fascia 0, stato: [np.float32(-4.5867), np.float32(87.37928), np.float32(100.0)]
# time 49, fascia 1, stato: [np.float32(-5.02265), np.float32(86.36934), np.float32(100.0)]
# time 50, fascia 2, stato: [np.float32(-4.931125), np.float32(87.15097), np.float32(100.0)]
# time 51, fascia 3, stato: [np.float32(-5.2774), np.float32(86.43096), np.float32(100.0)]
# time 52, fascia 4, stato: [np.float32(-5.3476), np.float32(86.54993), np.float32(100.0)]
# time 53, fascia 5, stato: [np.float32(-4.800925), np.float32(82.688576), np.float32(100.0)]
# time 54, fascia 6, stato: [np.float32(-5.9287), np.float32(82.074974), np.float32(100.0)]
# time 55, fascia 7, stato: [np.float32(-6.091625), np.float32(83.75331), np.float32(100.0)]
# time 56, fascia 8, stato: [np.float32(-1.79995), np.float32(78.5775), np.float32(100.0)]
# time 57, fascia 9, stato: [np.float32(-2.15545), np.float32(50.26876), np.float32(100.0)]
# time 58, fascia 10, stato: [np.float32(-0.0271), np.float32(48.896698), np.float32(100.0)]
# time 59, fascia 11, stato: [np.float32(0.085125), np.float32(53.24129), np.float32(100.0)]
# time 60, fascia 12, stato: [np.float32(0.8736), np.float32(54.79062), np.float32(100.0)]
# time 61, fascia 13, stato: [np.float32(0.84605), np.float32(65.618965), np.float32(100.0)]
# time 62, fascia 14, stato: [np.float32(-0.08925), np.float32(76.35178), np.float32(100.0)]
# time 63, fascia 15, stato: [np.float32(-0.504525), np.float32(85.06775), np.float32(100.0)]
# time 64, fascia 16, stato: [np.float32(0.25525), np.float32(88.775734), np.float32(100.0)]
# time 65, fascia 17, stato: [np.float32(-0.30715), np.float32(89.3943), np.float32(100.0)]
# time 66, fascia 18, stato: [np.float32(-0.404975), np.float32(89.73561), np.float32(100.0)]
# time 67, fascia 19, stato: [np.float32(-1.49855), np.float32(91.023636), np.float32(100.0)]
# time 68, fascia 20, stato: [np.float32(-1.774625), np.float32(91.16419), np.float32(100.0)]
# time 69, fascia 21, stato: [np.float32(-2.516), np.float32(83.84819), np.float32(100.0)]
# time 70, fascia 22, stato: [np.float32(-2.69645), np.float32(79.84807), np.float32(100.0)]
# time 71, fascia 23, stato: [np.float32(-3.2511), np.float32(85.61786), np.float32(100.0)]

# %%
print(temp_val[0][np.argmin(np.abs(temp_val[0]-(10)))])
# Out:
# 7.6187

# %%
print(temp_val[0])
# Out:
# [-15.5387 -15.0661 -14.5935 -14.1209 -13.6483 -13.1757 -12.7031 -12.2305
#  -11.7579 -11.2853 -10.8127 -10.3401  -9.8675  -9.3949  -8.9223  -8.4497
#   -7.9771  -7.5045  -7.0319  -6.5593  -6.0867  -5.6141  -5.1415  -4.6689
#   -4.1963  -3.7237  -3.2511  -2.7785  -2.3059  -1.8333  -1.3607  -0.8881
#   -0.4155   0.0571   0.5297   1.0023   1.4749   1.9475   2.4201   2.8927
#    3.3653   3.8379   4.3105   4.7831   5.2557   5.7283   6.2009   6.6735
#    7.1461   7.6187]

# %%
print(stage_cost([temp_val[0][15],humid_val[0][45]],[10,2.5]))
# Out:
# 21.8125

# %%
U_t=input_space(temp_val[0][15],humid_val[0][45],U_default)
#print(U_t)
print(depth_transition([temp_val[0][15],humid_val[0][45],depth_space[0]],[10,2.5]))
# Out:
# 11.5

# %%
print(temp_val[0][15])
print(humid_val[0][45])
# Out:
# -8.4497
# 91.71136

# %% [markdown]
# ### Implementazione algoritmo DP
# ---

# %%
def argmin(T_idx,RH_idx,d_idx,t,f_t):
    [T,RH,d]=state_space[f_t][T_idx,RH_idx,d_idx]
    U_t=input_space(T,RH,U_default)
    E_values=np.zeros(len(U_t))
    for u_idx,u in enumerate(U_t):
        E_values[u_idx]=stage_cost([T,RH,d],u)+expected_cost_to_go(T,RH,d,u,t,f_t)
    index=np.argmin(E_values)
    return U_t[index]
    
def expected_cost_to_go(T,RH,d,u,t,f_t):
    day=t//24
    if t==T-1:
        V=V_T
    else:
        V=V_list[f_t+1]
    d_next=depth_transition([T,RH,d],u)
    k=np.where(depth_space == d_next)[0][0]
    E_cost_to_go=0
    for i,T_next in enumerate(temp_val[f_t+1]):
        for j,RH_next in range(humid_val[f_t+1]):
            E_cost_to_go+=V[i,j,k,t+1]*P_list[f_t+1][state_to_index(T,RH,temp_val[f_t],humid_val[f_t]),state_to_index(T_next,RH_next,temp_val[f_t+1],humid_val[f_t+1])]
    return E_cost_to_go

T=72 #lunghezza time horizon in ore
n_days=72//24 #lunghezza time horizon in giorni
V_list=[np.zeros((n_T,n_RH,n_d,n_days),dtype=np.float32) for _ in range(n_fasce)] #lista di cost value functions, una per ogni fascia oraria
mu_star_list=[np.zeros((n_T,n_RH,n_d,n_days,2),dtype=np.float32) for _ in range(n_fasce)] # policy da trovare, per ogni fascia oraria
print(V_list[0].shape)
print(mu_star_list[0].shape)

# INIZIALIZZAZIONE
# loop over all the possible states
target_d_idx=np.where(depth_space == 50)[0][0] #indice di profondità da raggiungere
V_T=np.zeros(n_d)
for i in range(n_d): 
    if i<target_d_idx:
        V_T[i]=np.inf

# ITERAZIONI
for t in range(T-1,-1,-1): # loop over all the time instants in [T-1,...,0]
    # loop over all the states 
    print(f"Processing time {t}")
    f_t=t%24 #fascia a cui appartiene l'istante t
    for i,T in enumerate(n_T):
        for j,RH in enumerate(n_RH):
            for k,d in enumerate(n_d):
# Out:
# (50, 50, 201, 3)
# (50, 50, 201, 3, 2)
# '\nfor V_t_s in V_list:\n    for i in range(n_T):\n        for j in range(n_RH):\n            for k in range(target_d_idx,n_d):\n                V_t_s[i,j,k,T]=terminal_cost(X[i,j,k])\n'

# %%
print(depth_space)
print(np.where(depth_space == 50)[0][0])

# %%
[T,RH,d]=X[0,0,0]
print(T)
# Out:
# -16.70485

# %%
# Out:
# array([[[-15.5387  ,  23.159437,   0.      ],
#         [-15.5387  ,  23.159437,   0.5     ],
#         [-15.5387  ,  23.159437,   1.      ],
#         ...,
#         [-15.5387  ,  23.159437,  99.      ],
#         [-15.5387  ,  23.159437,  99.5     ],
#         [-15.5387  ,  23.159437, 100.      ]],
#
#        [[-15.5387  ,  24.682814,   0.      ],
#         [-15.5387  ,  24.682814,   0.5     ],
#         [-15.5387  ,  24.682814,   1.      ],
#         ...,
#         [-15.5387  ,  24.682814,  99.      ],
#         [-15.5387  ,  24.682814,  99.5     ],
#         [-15.5387  ,  24.682814, 100.      ]],
#
#        [[-15.5387  ,  26.20619 ,   0.      ],
#         [-15.5387  ,  26.20619 ,   0.5     ],
#         [-15.5387  ,  26.20619 ,   1.      ],
#         ...,
#         [-15.5387  ,  26.20619 ,  99.      ],
#         [-15.5387  ,  26.20619 ,  99.5     ],
#         [-15.5387  ,  26.20619 , 100.      ]],
#
#        ...,
#
#        [[-15.5387  ,  94.75811 ,   0.      ],
#         [-15.5387  ,  94.75811 ,   0.5     ],
#         [-15.5387  ,  94.75811 ,   1.      ],
#         ...,
#         [-15.5387  ,  94.75811 ,  99.      ],
#         [-15.5387  ,  94.75811 ,  99.5     ],
#         [-15.5387  ,  94.75811 , 100.      ]],
#
#        [[-15.5387  ,  96.28149 ,   0.      ],
#         [-15.5387  ,  96.28149 ,   0.5     ],
#         [-15.5387  ,  96.28149 ,   1.      ],
#         ...,
#         [-15.5387  ,  96.28149 ,  99.      ],
#         [-15.5387  ,  96.28149 ,  99.5     ],
#         [-15.5387  ,  96.28149 , 100.      ]],
#
#        [[-15.5387  ,  97.80486 ,   0.      ],
#         [-15.5387  ,  97.80486 ,   0.5     ],
#         [-15.5387  ,  97.80486 ,   1.      ],
#         ...,
#         [-15.5387  ,  97.80486 ,  99.      ],
#         [-15.5387  ,  97.80486 ,  99.5     ],
#         [-15.5387  ,  97.80486 , 100.      ]]],
#       shape=(50, 201, 3), dtype=float32)
